# %% [markdown]
# 1768. Merge Strings Alternately
#
# You are given two strings word1 and word2. Merge the strings by adding letters in alternating order, starting with word1. If a string is longer than the other, append the additional letters onto the end of the merged string.
#
# Return the merged string.
#
#
#
# Example 1:
#
# Input: word1 = "abc", word2 = "pqr"
# Output: "apbqcr"
# Explanation: The merged string will be merged as so:
# word1:  a   b   c
# word2:    p   q   r
# merged: a p b q c r
# Example 2:
#
# Input: word1 = "ab", word2 = "pqrs"
# Output: "apbqrs"
# Explanation: Notice that as word2 is longer, "rs" is appended to the end.
# word1:  a   b
# word2:    p   q   r   s
# merged: a p b q   r   s
# Example 3:
#
# Input: word1 = "abcd", word2 = "pq"
# Output: "apbqcd"
# Explanation: Notice that as word1 is longer, "cd" is appended to the end.
# word1:  a   b   c   d
# word2:    p   q
# merged: a p b q c   d
#
#
# Constraints:
#
# 1 <= word1.length, word2.length <= 100
# word1 and word2 consist of lowercase English letters.
#
# case1
# word1 =
# "abc"
# word2 =
# "pqr"
#
# case2
# word1 =
# "ab"
# word2 =
# "pqrs"
#
# case3
# word1 =
# "abcd"
# word2 =
# "pq"

# %%
def mergeAlternately(self, word1: str, word2: str) -> str:
    result = "" #сюда мы пишем наши значения
        
    for i in range(min(len(word1), len(word2))): #для позиции в списке длиной len(word1), 
        #len(word2) 
        result += word1[i] #в result пишем значение кармашика word1 на позиции
        result += word2[i] #в result пишем значение кармашика word2 на позиции
        # как понять что он пишет их по очереди я не понимаю 

        
        # если word1 длиннее - дописываем остаток word1
    if len(word1) > len(word2):
        result += word1[len(word2):] #я не понимаю как это работает len(word2):
        
        # если word2 длиннее - дописываем остаток word2
    if len(word2) > len(word1):
        result += word2[len(word1):]  #я не понимаю как это работает len(word1):
        
    return result
# Out:
# Running cells with 'Python 3.13.3' requires the ipykernel package.
#
# <a href='command:jupyter.createPythonEnvAndSelectController'>Create a Python Environment</a> with the required packages.
#
# Or install 'ipykernel' using the command: '/opt/homebrew/bin/python3 -m pip install ipykernel -U --user --force-reinstall'
